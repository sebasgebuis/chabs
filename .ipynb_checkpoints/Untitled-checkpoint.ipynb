# %%
import pandas as pd

# %%
data = pd.read_csv('melbourne_ta_reviews.csv', sep = ',')

# %%
display(data)
# Out:
#                              name  rankingPosition priceLevel    category  \
# 0    Hopetoun Tea Rooms est. 1892               26   $$ - $$$  restaurant
# 1               Da Guido La Pasta                2   $$ - $$$  restaurant
# 2                  Foglia di Fico                3   $$ - $$$  restaurant
# 3              Pidapipo Gelateria               11          $  restaurant
# 4                        Kazuki's                9       $$$$  restaurant
# ..                            ...              ...        ...         ...
# 495                    Bella Cosi              446   $$ - $$$  restaurant
# 496           At Ease - Easy Thai              437          $  restaurant
# 497                 Lolo and Wren              436   $$ - $$$  restaurant
# 498                     Thai city              438   $$ - $$$  restaurant
# 499                   Tokui Sushi              429          $  restaurant
#
#      rating                                            address  \
# ...

# %%
cat1 = data[data['priceLevel'] == '$$ - $$$'].sort_values(by = 'rankingPosition').head(5)
display(cat1)

for index, row in cat1.iterrows():
    print(row['name'])
# Out:
#                         name  rankingPosition priceLevel    category  rating  \
# 359     Mister and Miss Cafe                1   $$ - $$$  restaurant     4.0
# 379      Fifteen Pounds Cafe                1   $$ - $$$  restaurant     4.5
# 313                400 Gradi                1   $$ - $$$  restaurant     4.0
# 34                    Scopri                1   $$ - $$$  restaurant     5.0
# 309  GRK Greek Kitchen & Bar                1   $$ - $$$  restaurant     4.5
#
#                                                address  numberOfReviews
# 359  Mont Albert Victoria 711-713 Whitehorse Rd, Mo...              199
# 379  21 Railway Place, Fairfield, Yarra, Victoria 3...               84
# 313  99 Lygon St, Brunswick West, Moreland, Victori...              773
# 34   191 Nicholson St Carlton, Melbourne, Victoria ...             1049
# 309  845/847 High St, Thornbury, Darebin, Victoria ...              115
# Mister and Miss Cafe
# Fifteen Pounds Cafe
# 400 Gradi
# Scopri
# ...

# %%
Betty’s Burgers & Concrete Codata[data['priceLevel'] == '$$$$'].sort_values(by = 'rankingPosition').head(5)
# Out:
#                            name  rankingPosition priceLevel    category  \
# 162                   Centonove                1       $$$$  restaurant
# 299  Amaru Melbourne Restaurant                1       $$$$  restaurant
# 287                  Esca Grill                1       $$$$  restaurant
# 245                    Matteo's                1       $$$$  restaurant
# 186                      Attica                1       $$$$  restaurant
#
#      rating                                            address  \
# 162     4.5  109 Cotham Rd, Kew, Boroondara, Victoria 3101 ...
# 299     4.5  Shop 5 1121 High St, Armadale, Stonnington, Vi...
# 287     4.5  650 Mt Alexander Rd, Moonee Ponds, Moonee Vall...
# 245     4.5  533 Brunswick St Melbourne, North Fitzroy, Yar...
# 186     4.5  74 Glen Eira Rd, Ripponlea, Port Phillip, Vict...
#
#      numberOfReviews
# 162              252
# 299              118
# 287              345
# 245              378
# 186              626

# %%
len('Betty’s Burgers & Concrete Co')
# Out:
# 29
